# %% [markdown]
# <a href="https://colab.research.google.com/github/Jrojas743/IA/blob/main/copia_cosos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

import seaborn as sns
#seaborn tambien para graficar

#graficar
import matplotlib.pyplot as plt

import matplotlib.ticker as ticker

#sistema operativo
import os

#leer archivos de web
import urllib

# %%
urlvariables="https://raw.githubusercontent.com/adiacla/bigdata/master/variable.txt"
variables=urllib.request.urlopen("https://raw.githubusercontent.com/adiacla/bigdata/master/variable.txt")
for linea in variables:
  print(linea.decode("utf-8"))
# Out:
# price: precio de la vivienda.
#
# lotSize: metros cuadrados de la vivienda.
#
# age: antigüedad de la vivienda.
#
# landValue: valor del terreno.
#
# livingArea: metros cuadrados habitables.
#
# pctCollege: porcentaje del vecindario con título universitario.
#
# bedrooms: número de dormitorios.
#
# firplaces: número de chimeneas.
#
# bathrooms: número de cuartos de baño (el valor 0.5 hace referencia a cuartos de baño sin ducha).
#
# rooms: número de habitaciones.
#
# heating: tipo de calefacción.
#
# fuel: tipo de alimentación de la calefacción (gas, electricidad o diesel).
#
# sewer: tipo de desagüe.
#
# waterfront: si la vivienda tiene vistas al lago.
#
# newConstruction: si la vivienda es de nueva construcción.
#
# centralAir: si la vivienda tiene aire acondicionado.
#
# built date: fecha de contruida
#
# property code: número catastral
#
# mtrsmyroom: Area por salón
#
# category: Tipo de construcción

# %%
url="https://raw.githubusercontent.com/adiacla/bigdata/master/casasOrg.csv"
df=pd.read_csv(url,sep=";")
#sep para separar por comas
df
# Out:
#        price  lotSize  age  landValue  livingArea  pctCollege  bedrooms  \
# 0     132500     0.09   42      50000       906.0          35         2
# 1     181115     0.92    0      22300      1953.0          51         3
# 2     132500     0.09   42      50000       906.0          35         2
# 3     181115     0.92    0      22300      1953.0          51         3
# 4     109000     0.19  133       7300      1944.0          51         4
# ...      ...      ...  ...        ...         ...         ...       ...
# 1725  289000     0.38   32      24200      2310.0          61         5
# 1726  285000     0.94   37      36200      2564.0          61         4
# 1727  194900     0.39    9      20400      1099.0          51         2
# 1728  125000     0.24   48      16800      1225.0          51         3
# 1729  111300     0.59   86      26000      1959.0          51         3
#
#       fireplaces  bathrooms  rooms          heating      fuel  \
# ...

# %%
df.head(20)
# Out:
#      price  lotSize    age  landValue  livingArea  pctCollege  bedrooms  \
# 0   132500     0.09     42      50000       906.0          35         2
# 1   181115     0.92      0      22300      1953.0          51         3
# 2   132500     0.09     42      50000       906.0          35         2
# 3   181115     0.92      0      22300      1953.0          51         3
# 4   109000     0.19    133       7300      1944.0          51         4
# 5   155000     0.41     13      18700      1944.0          51         3
# 6    86060     0.11      0      15000       840.0          51         2
# 7   120000     0.68     31      14000      1152.0          22         4
# 8   153000     0.40     33      23300      2752.0          51         4
# 9   170000     1.21     23      14600      1662.0          35         4
# 10   90000     0.83  36000      22200      1632.0          51         3
# 11  122900     1.94      4      21200      1416.0          44         3
# ...

# %%
df.age=df.age+3    #recorrer toda la matriz
df
# Out:
#        price  lotSize  age  landValue  livingArea  pctCollege  bedrooms  \
# 0     132500     0.09   45      50000       906.0          35         2
# 1     181115     0.92    3      22300      1953.0          51         3
# 2     132500     0.09   45      50000       906.0          35         2
# 3     181115     0.92    3      22300      1953.0          51         3
# 4     109000     0.19  136       7300      1944.0          51         4
# ...      ...      ...  ...        ...         ...         ...       ...
# 1725  289000     0.38   35      24200      2310.0          61         5
# 1726  285000     0.94   40      36200      2564.0          61         4
# 1727  194900     0.39   12      20400      1099.0          51         2
# 1728  125000     0.24   51      16800      1225.0          51         3
# 1729  111300     0.59   89      26000      1959.0          51         3
#
#       fireplaces  bathrooms  rooms          heating      fuel  \
# ...

# %%
df.columns=["precio","metros_totales", "antiguedad", "precio_terreno", "metros_habitables","universitarios",
            "dormitorios", "chimenea", "baños", "habitaciones","calefaccion","consumo_calefacion",
            "desague", "vistas_lago", "nueva_construccion","aire_acondicionado","fecha construido","numero catastro","MetroPorSalon","categoria"]

# %%
dfc=df.copy()  #copia de trabajo, mientras que el otro df sera el original

# %%
dfc[dfc.duplicated(subset=["numero catastro"])]  #mostrar los duplicados del numero catrastro
# Out:
#    precio  metros_totales  antiguedad  precio_terreno  metros_habitables  \
# 2  132500            0.09          45           50000              906.0
# 3  181115            0.92           3           22300             1953.0
#
#    universitarios  dormitorios  chimenea  baños  habitaciones  \
# 2              35            2       1.0    1.0             5
# 3              51            3       NaN    2.5             6
#
#        calefaccion consumo_calefacion  desague vistas_lago nueva_construccion  \
# 2         electric           electric   septic          No                 No
# 3  hot water/steam                gas   septic          No                 No
#
#   aire_acondicionado fecha construido       numero catastro MetroPorSalon  \
# 2                 No       21/08/1978  UC0101375548AWS38852       10181,2
# 3                 No       10/08/2020  UC0101385720AWS27109   4042,166667
#
#   categoria
# 2        Lx
# 3        Mx

# %%
dfc.drop_duplicates(subset=["numero catastro"], inplace=True)  #se borran los duplicados del coso

# %%
dfc.drop("fecha construido",axis=1,inplace=True)  #para borrar la columna porque es la misma cosa que age tonces es innecesario tnerla en el dataframe
#axis 1 es igual a columnas
#axis 0 es igual a filas
#implace True es para hacer el cambio permantente y salga la columna borrada
dfc
# Out:
#       precio  metros_totales  antiguedad  precio_terreno  metros_habitables  \
# 0     132500            0.09          45           50000              906.0
# 1     181115            0.92           3           22300             1953.0
# 4     109000            0.19         136            7300             1944.0
# 5     155000            0.41          16           18700             1944.0
# 6      86060            0.11           3           15000              840.0
# ...      ...             ...         ...             ...                ...
# 1725  289000            0.38          35           24200             2310.0
# 1726  285000            0.94          40           36200             2564.0
# 1727  194900            0.39          12           20400             1099.0
# 1728  125000            0.24          51           16800             1225.0
# 1729  111300            0.59          89           26000             1959.0
#
# ...

# %%
df.antiguedad.plot.hist() #graficar en un histograma
# Out:
# <Axes: ylabel='Frequency'>

# %%
dfc[dfc["antiguedad"]>1000]   #filtro para encontrar los datos con antiguedad +1000 año

#dfc["antiguedad"]  es lo mismo que dfc.antiguedad
# Out:
#      precio  metros_totales  antiguedad  precio_terreno  metros_habitables  \
# 10    90000            0.83       36003           22200             1632.0
# 51   108000            0.90       48003           19000             1042.0
# 269  114000            0.26       26003            4600             1700.0
# 494  325000            0.80      134003           18100             2463.0
#
#      universitarios  dormitorios  chimenea  baños  habitaciones  \
# 10               51            3       NaN    1.5             8
# 51               71            2       1.0    2.0             3
# 269              39            3       1.0    1.5             4
# 494              60            5       2.0    2.5            12
#
#          calefaccion consumo_calefacion            desague vistas_lago  \
# 10          electric           electric             septic          No
# 51           Hot Air                gas             septic          No
# ...

# %%
dfc.antiguedad.value_counts().sort_index(ascending=False)      #sort index para ordenarlos
# Out:
# 134003     1
# 48003      1
# 36003      1
# 26003      1
# 228        1
#           ..
# 7         21
# 6         29
# 5         17
# 4         75
# 3         83
# Name: antiguedad, Length: 140, dtype: int64

# %%
dfc.antiguedad=np.where(dfc.antiguedad<1000,dfc.antiguedad,((dfc.antiguedad-3)/1000)+3)  #los valores de antiguedad menores de mil, dejarlos asi, mientras que los mayores restarle 3 y dividrlo entre mil
dfc.head(9)
# Out:
#     precio  metros_totales  antiguedad  precio_terreno  metros_habitables  \
# 0   132500            0.09        45.0           50000              906.0
# 1   181115            0.92         3.0           22300             1953.0
# 4   109000            0.19       136.0            7300             1944.0
# 5   155000            0.41        16.0           18700             1944.0
# 6    86060            0.11         3.0           15000              840.0
# 7   120000            0.68        34.0           14000             1152.0
# 8   153000            0.40        36.0           23300             2752.0
# 9   170000            1.21        26.0           14600             1662.0
# 10   90000            0.83        39.0           22200             1632.0
#
#     universitarios  dormitorios  chimenea  baños  habitaciones  \
# 0               35            2       1.0    1.0             5
# 1               51            3       NaN    2.5             6
# ...

# %%
dfc.antiguedad=dfc.antiguedad.astype("int32")
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1728 entries, 0 to 1729
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   precio              1728 non-null   int64
#  1   metros_totales      1728 non-null   float64
#  2   antiguedad          1728 non-null   int32
#  3   precio_terreno      1728 non-null   int64
#  4   metros_habitables   1723 non-null   float64
#  5   universitarios      1728 non-null   int64
#  6   dormitorios         1728 non-null   int64
#  7   chimenea            988 non-null    float64
#  8   baños               1728 non-null   float64
#  9   habitaciones        1728 non-null   int64
#  10  calefaccion         1728 non-null   object
#  11  consumo_calefacion  1728 non-null   object
#  12  desague             1722 non-null   object
#  13  vistas_lago         1728 non-null   object
#  14  nueva_construccion  1728 non-null   object
# ...

# %%
dfc.isnull().sum()
# Out:
# precio                  0
# metros_totales          0
# antiguedad              0
# precio_terreno          0
# metros_habitables       5
# universitarios          0
# dormitorios             0
# chimenea              740
# baños                   0
# habitaciones            0
# calefaccion             0
# consumo_calefacion      0
# desague                 6
# vistas_lago             0
# nueva_construccion      0
# aire_acondicionado      0
# numero catastro         0
# MetroPorSalon           0
# categoria               0
# dtype: int64

# %%
dfc.chimenea.fillna(0,inplace=True)
dfc.desague.fillna(method="ffill",inplace=True)  #para hacer el after

# %%
media=df.metros_habitables.mean() #promedio
dfc.metros_habitables.fillna(media,inplace=True)
#ocosoco

# %%
dfc.drop("numero catastro",axis=1,inplace=True)  #BORRAR LA COLUMNA  NUMERO CATASTRO

# %%
dfc
# Out:
#       precio  metros_totales  antiguedad  precio_terreno  metros_habitables  \
# 0     132500            0.09          45           50000              906.0
# 1     181115            0.92           3           22300             1953.0
# 4     109000            0.19         136            7300             1944.0
# 5     155000            0.41          16           18700             1944.0
# 6      86060            0.11           3           15000              840.0
# ...      ...             ...         ...             ...                ...
# 1725  289000            0.38          35           24200             2310.0
# 1726  285000            0.94          40           36200             2564.0
# 1727  194900            0.39          12           20400             1099.0
# 1728  125000            0.24          51           16800             1225.0
# 1729  111300            0.59          89           26000             1959.0
#
# ...

# %%
dfc.describe(include=["float","int"])
# Out:
#               precio  metros_totales   antiguedad  precio_terreno  \
# count    1728.000000     1728.000000  1728.000000     1728.000000
# mean   211966.705440        0.500214    30.916088    34557.187500
# std     98441.391015        0.698680    29.209988    35021.168056
# min      5000.000000        0.000000     3.000000      200.000000
# 25%    145000.000000        0.170000    16.000000    15100.000000
# 50%    189900.000000        0.370000    22.000000    25000.000000
# 75%    259000.000000        0.540000    37.000000    40200.000000
# max    775000.000000       12.200000   228.000000   412600.000000
#
#        metros_habitables  universitarios  dormitorios     chimenea  \
# count        1728.000000     1728.000000  1728.000000  1728.000000
# mean         1754.982657       55.567708     3.154514     0.601852
# std           619.935535       10.333581     0.817351     0.556102
# min           616.000000       20.000000     1.000000     0.000000
# ...

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1728 entries, 0 to 1729
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   precio              1728 non-null   int64
#  1   metros_totales      1728 non-null   float64
#  2   antiguedad          1728 non-null   int32
#  3   precio_terreno      1728 non-null   int64
#  4   metros_habitables   1728 non-null   float64
#  5   universitarios      1728 non-null   int64
#  6   dormitorios         1728 non-null   int64
#  7   chimenea            1728 non-null   float64
#  8   baños               1728 non-null   float64
#  9   habitaciones        1728 non-null   int64
#  10  calefaccion         1728 non-null   object
#  11  consumo_calefacion  1728 non-null   object
#  12  desague             1728 non-null   object
#  13  vistas_lago         1728 non-null   object
#  14  nueva_construccion  1728 non-null   object
# ...

# %%
dfc.MetroPorSalon.replace(",",".",inplace=True,regex=True)   #regex para que pueda buscar la coma en todo el string, sino solo buscaria un campo solo con una coma y no cambiaria nada
dfc.MetroPorSalon=dfc.MetroPorSalon.astype("float")

# %%
dfc.chimenea=dfc.chimenea.apply(np.ceil)
dfc.baños=dfc.baños.apply(np.ceil)   #np ceil sirve para redondear la parte de baños porque no pueden ser 2.5 baños y redondea hacia arriba, hacia abajo seria np.floor
dfc.chimenea=dfc.chimenea.astype(int)
dfc.baños=dfc.baños.astype(int)

# %% [markdown]
# ### Tratamiento de datos categoricos (tipo objetc, string, etc)

# %%
#dfc.describe(include="object")
dfc.select_dtypes(include="object")
# Out:
#           calefaccion consumo_calefacion            desague vistas_lago  \
# 0            electric           electric             septic          No
# 1     hot water/steam               gas              septic          No
# 4     hot water/steam                gas  public/commercial          No
# 5             Hot Air                gas             septic          No
# 6             hot air                gas  public/commercial          No
# ...               ...                ...                ...         ...
# 1725  hot water/steam                gas  public/commercial          No
# 1726  hot water/steam                gas  public/commercial          No
# 1727          hot air                gas  public/commercial          No
# 1728          hot air                gas  public/commercial          No
# 1729          hot air                gas             septic          No
#
#      nueva_construccion aire_acondicionado categoria
# ...

# %%
dfc.calefaccion=dfc.calefaccion.str.lower()  #pasamos a minusculas a todo y ahi ya se une ambas hot air y Hot air
dfc.calefaccion.hist()    # se ve que se repite hot air porque uno esta en mayuscula, tonces toca unirlos para que slaga solo 1
# Out:
# <Axes: >

# %%
pd.value_counts(dfc.calefaccion)
# Out:
# hot air            1121
# electric            305
# hot water/steam     302
# Name: calefaccion, dtype: int64

# %%
columnas_categoricas=dfc.select_dtypes(include="object")
columnas_categoricas.columns

for i,columna in enumerate(columnas_categoricas):
  print("posicion: ",i,"  la columna: ",columna)
# Out:
# posicion:  0   la columna:  calefaccion
# posicion:  1   la columna:  consumo_calefacion
# posicion:  2   la columna:  desague
# posicion:  3   la columna:  vistas_lago
# posicion:  4   la columna:  nueva_construccion
# posicion:  5   la columna:  aire_acondicionado
# posicion:  6   la columna:  categoria

# %%
dfc.consumo_calefacion=dfc.consumo_calefacion.str.strip()   #permite eliminar los espacios adelante y atras de las variables cualitativas

# %%
columnas_categoricas=dfc.select_dtypes(include="object")
columnas_categoricas.columns

for i,columna in enumerate(columnas_categoricas):
  print(pd.value_counts(dfc[columna]))
  print("\n")
# Out:
# hot air            1121
# electric            305
# hot water/steam     302
# Name: calefaccion, dtype: int64
#
#
# gas         1197
# electric     315
# oil          216
# Name: consumo_calefacion, dtype: int64
#
#
# public/commercial    1213
# septic                503
# none                   12
# Name: desague, dtype: int64
#
#
# No     1713
# Yes      15
# Name: vistas_lago, dtype: int64
#
#
# No     1647
# Yes      81
# Name: nueva_construccion, dtype: int64
#
#
# No     1093
# Yes     635
# Name: aire_acondicionado, dtype: int64
#
#
# Mx    620
# S     594
# M     256
# Lx    164
# L      93
# Sx      1
# Name: categoria, dtype: int64

# %%
dic={"Lx": "L",
     "Sx":"S",
     "Mx":"M"}
dfc.categoria.replace(dic,inplace=True)
pd.value_counts(dfc.categoria,sort=True,ascending=True)
# Out:
# L    257
# S    595
# M    876
# Name: categoria, dtype: int64

# %%
fig, ax= plt.subplots(figsize=(4,3))
ax.hist(x=dfc.calefaccion,color="orange")
plt.title("histograma de calefaccion", loc="left")
ax.grid()
plt.xlabel("Tipos de calefaccion",color="blue")
plt.ylabel("Cantidad del dataset",color="blue")
# Out:
# Text(0, 0.5, 'Cantidad del dataset')

# %% [markdown]
# **GRAFICOS DE VARIABLES CUALITATIVAS**

# %%
columnas_categoricas=dfc.select_dtypes(include="object")  #el include objecto solo coge las tipo objeto o string, que son categoricas (de texto y no cuantitativas)
columnas_categoricas.columns

#defnir los parametros de la grafica
fig,axes=plt.subplots(nrows=3,ncols=3,figsize=(10,10))
axes=axes.flat





for i,columna in enumerate(columnas_categoricas):
  dfc[columna].value_counts().plot.barh(ax=axes[i])
  axes[i].set_title(columna,fontsize=10,fontweight="bold")
  axes[i].tick_params(labelsize=6)

#delaxes para borrar las graficas en las posiciones 7 y 8
fig.delaxes(axes[7])
fig.delaxes(axes[8])

#ajusta los tamaños de las graficas entre si y quedan super organizadas
fig.tight_layout()


fig.subplots_adjust(top=0.9)
#titulo superior
fig.suptitle("Distribucion de las variables cualitativas",fontsize=20,fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Distribucion de las variables cualitativas')

# %% [markdown]
# **Vamos a corregir consumo caleffacion en la instancia gas, eliminamos vista al lago porque estan demasiado desbalanceadas y elminamos nueva construccion porque ya esta relacionada con la edad y no hace falta.**

# %%
#corregimos calefaccion con strip

dfc.drop(["vistas_lago","nueva_construccion"],axis=1,inplace=True)

# %%
dfc
# Out:
#       precio  metros_totales  antiguedad  precio_terreno  metros_habitables  \
# 0     132500            0.09          45           50000              906.0
# 1     181115            0.92           3           22300             1953.0
# 4     109000            0.19         136            7300             1944.0
# 5     155000            0.41          16           18700             1944.0
# 6      86060            0.11           3           15000              840.0
# ...      ...             ...         ...             ...                ...
# 1725  289000            0.38          35           24200             2310.0
# 1726  285000            0.94          40           36200             2564.0
# 1727  194900            0.39          12           20400             1099.0
# 1728  125000            0.24          51           16800             1225.0
# 1729  111300            0.59          89           26000             1959.0
#
# ...

# %% [markdown]
# Analisis de variables numericas
#
# Analsis de outliers

# %%
#guardar el archivo del dataframe
dfc.to_csv("datos_limpios.csv")

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1728 entries, 0 to 1729
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   precio              1728 non-null   int64
#  1   metros_totales      1728 non-null   float64
#  2   antiguedad          1728 non-null   int32
#  3   precio_terreno      1728 non-null   int64
#  4   metros_habitables   1728 non-null   float64
#  5   universitarios      1728 non-null   int64
#  6   dormitorios         1728 non-null   int64
#  7   chimenea            1728 non-null   int64
#  8   baños               1728 non-null   int64
#  9   habitaciones        1728 non-null   int64
#  10  calefaccion         1728 non-null   object
#  11  consumo_calefacion  1728 non-null   object
#  12  desague             1728 non-null   object
#  13  aire_acondicionado  1728 non-null   object
#  14  MetroPorSalon       1728 non-null   float64
# ...

# %%
columnas_numericas=dfc.select_dtypes(include=["int64","float64","int32"])
columnas_numericas
# Out:
#       precio  metros_totales  antiguedad  precio_terreno  metros_habitables  \
# 0     132500            0.09          45           50000              906.0
# 1     181115            0.92           3           22300             1953.0
# 4     109000            0.19         136            7300             1944.0
# 5     155000            0.41          16           18700             1944.0
# 6      86060            0.11           3           15000              840.0
# ...      ...             ...         ...             ...                ...
# 1725  289000            0.38          35           24200             2310.0
# 1726  285000            0.94          40           36200             2564.0
# 1727  194900            0.39          12           20400             1099.0
# 1728  125000            0.24          51           16800             1225.0
# 1729  111300            0.59          89           26000             1959.0
#
# ...

# %%
#recorrer todas las columnas numericas para mostrar sus cuantiles (Q1 Q2 Q3)

for i,columna in enumerate(columnas_numericas):
  cuantiles=dfc[columna].quantile([0.25,0.5,0.75])
  print(columna)
  print(cuantiles,"\n  \n")
# Out:
# precio
# 0.25    145000.0
# 0.50    189900.0
# 0.75    259000.0
# Name: precio, dtype: float64
#
#
# metros_totales
# 0.25    0.17
# 0.50    0.37
# 0.75    0.54
# Name: metros_totales, dtype: float64
#
#
# antiguedad
# 0.25    16.0
# 0.50    22.0
# 0.75    37.0
# Name: antiguedad, dtype: float64
#
#
# precio_terreno
# 0.25    15100.0
# 0.50    25000.0
# 0.75    40200.0
# Name: precio_terreno, dtype: float64
#
#
# metros_habitables
# 0.25    1300.00
# 0.50    1634.50
# 0.75    2137.75
# Name: metros_habitables, dtype: float64
#
#
# universitarios
# 0.25    52.0
# 0.50    57.0
# 0.75    64.0
# Name: universitarios, dtype: float64
#
#
# dormitorios
# 0.25    3.0
# 0.50    3.0
# 0.75    4.0
# Name: dormitorios, dtype: float64
#
#
# chimenea
# 0.25    0.0
# 0.50    1.0
# 0.75    1.0
# Name: chimenea, dtype: float64
#
#
# baños
# 0.25    2.0
# 0.50    2.0
# 0.75    3.0
# Name: baños, dtype: float64
#
#
# habitaciones
# 0.25    5.00
# 0.50    7.00
# 0.75    8.25
# ...

# %%
fig, ax = plt.subplots()
ax.boxplot(dfc.metros_totales)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x79485bea9fc0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x79485beaa500>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x79485bea9d20>],
#  'medians': [<matplotlib.lines.Line2D at 0x79485beaaa40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x79485beaace0>],
#  'means': []}

# %%
cuantiles_mt=dfc["metros_totales"].quantile([0.25,0.5,0.75])
cuantiles_mt
Q1=cuantiles_mt[0.25]
Q3=cuantiles_mt[0.75]

#IQR es rango intercuartil
IQR=Q3-Q1
bigoteSup=Q3+(IQR*1.5)
bigoteInf=Q1-(IQR*1.5)
print(bigoteInf,bigoteSup)
# Out:
# -0.3849999999999999 1.095

# %%
#filtrar el dataframe con una o mas condiciones
dfc[dfc.metros_totales>bigoteSup]
dfc[dfc.baños<1]
# Out:
#       precio  metros_totales  antiguedad  precio_terreno  metros_habitables  \
# 1495  195900             0.4          37           30000             1672.0
#
#       universitarios  dormitorios  chimenea  baños  habitaciones calefaccion  \
# 1495              64            3         1      0             5     hot air
#
#      consumo_calefacion            desague aire_acondicionado  MetroPorSalon  \
# 1495                gas  public/commercial                 No         6334.4
#
#      categoria
# 1495         M

# %%
def outlier(dfc,columnas_numericas):
  fig,axes=plt.subplots(nrows=3,ncols=4,figsize=(10,10))
  axes=axes.flat

  for i,columna in  enumerate(columnas_numericas):
    dfc[columna].plot.box(ax=axes[i])
    axes[i].set_title(columna,fontsize=10,fontweight="bold")
    axes[i].tick_params(labelsize=6)

  fig.tight_layout()
  fig.delaxes(axes[11]) #Borras graficos vacios
  return
outlier(dfc,columnas_numericas)

# %%
for i,columna in enumerate(columnas_numericas):
  cuantiles=dfc[columna].quantile([0.25,0.75])
  Q1=cuantiles[0.25]
  Q3=cuantiles[0.75]

#IQR es rango intercuartil
  IQR=Q3-Q1
  bigoteSup=Q3+(IQR*1.5)
  bigoteInf=Q1-(IQR*1.5)
  print(columna)
  print("bigote inf: ",bigoteInf, "bigote superior:" ,bigoteSup, "\n")
# Out:
# precio
# bigote inf:  -26000.0 bigote superior: 430000.0
#
# metros_totales
# bigote inf:  -0.3849999999999999 bigote superior: 1.095
#
# antiguedad
# bigote inf:  -15.5 bigote superior: 68.5
#
# precio_terreno
# bigote inf:  -22550.0 bigote superior: 77850.0
#
# metros_habitables
# bigote inf:  43.375 bigote superior: 3394.375
#
# universitarios
# bigote inf:  34.0 bigote superior: 82.0
#
# dormitorios
# bigote inf:  1.5 bigote superior: 5.5
#
# chimenea
# bigote inf:  -1.5 bigote superior: 2.5
#
# baños
# bigote inf:  0.5 bigote superior: 4.5
#
# habitaciones
# bigote inf:  0.125 bigote superior: 13.125
#
# MetroPorSalon
# bigote inf:  -3688.7678568750007 bigote superior: 12507.660714125

# %%
#quitar outliers

bigoteSup,bigoteInf=bigotes(dfc,"antiguedad")
print(bigoteInf,bigoteSup)
#dfc[dfc.antiguedad>bigoteSup]

# %%
#filtrar el dataframe antiguedad (outlayer)
def bigotes(dfc,columna):
  cuantiles_mt=dfc[columna].quantile([0.25,0.5,0.75])
  cuantiles_mt
  Q1=cuantiles_mt[0.25]
  Q3=cuantiles_mt[0.75]

  #IQR es rango intercuartil
  IQR=Q3-Q1
  bigoteSup=Q3+(IQR*1.5)
  bigoteInf=Q1-(IQR*1.5)

  return bigoteSup,bigoteInf
# Out:
# -15.5 61.5
#       precio  metros_totales  antiguedad  precio_terreno  metros_habitables  \
# 137   119900            1.03          66           41500             1701.0
# 349   154300            0.42          64           14700             1260.0
# 438   163000            0.15          67           36000             1092.0
# 460    20000            0.52          62            8000              936.0
# 476   129900            0.24          67            1400             1120.0
# 542   198500            0.10          66           85000             1680.0
# 571   126000            0.68          67           84200             1080.0
# 697   276000            0.21          65          107000             1579.0
# 756   119000            0.15          68            2500             1152.0
# 1527  194000            6.15          67           73500             1960.0
# 1616  155000            0.57          62           29900             1498.0
#
# ...

# %%
#quitar los outliers
print("Se tienen %i registros" %(len(dfc)))
dfc=dfc[dfc.antiguedad<=bigoteSup]
print("Quedaron %i registros" %(len(dfc)))
# Out:
# Se tienen 1728 registros
# Quedaron 1580 registros

# %%
outlier(dfc,columnas_numericas)

# %%
#
bigoteSupm,bigoteInf=bigotes(dfc,"metros_habitables")
print(bigoteInf,bigoteSup)
print("Se tienen %i registros" %(len(dfc)))
dfc=dfc[dfc.metros_habitables<=bigoteSup]




bigoteSupm,bigoteInf=bigotes(dfc,"MetroPorSalon")
print(bigoteInf,bigoteSup)
print("Se tienen %i registros" %(len(dfc)))
dfc=dfc[dfc["MetroPorSalon"]<=bigoteSup]

print("Quedaron %i registros" %(len(dfc)))
# Out:
# -15.5 3434.0
# Se tienen 1568 registros
# Quedaron 1566 registros

# %% [markdown]
# #Correlación variables numéricas
# Algunos modelos (LM, GLM, ...) se ven perjudicados si incorporan predictores altamente correlacionados. Por esta razón, es conveniente estudiar el grado de correlación entre las variables disponibles.

# %% [markdown]
# Cuando hayan 2 columnas de alta correlacion, quitar la de menor varianxa

# %%
fig,ax = plt.subplots(1,1, figsize=(6,4))
ax.scatter(x=dfc.precio, y=dfc.precio_terreno, alpha=0.4)
plt.show()

# %%
fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(9, 5))
axes = axes.flat
columnas_numericas=dfc.select_dtypes(include=["int64","float64","int32"]).columns
columnas_numericas = columnas_numericas.drop('precio')

for i, colum in enumerate(columnas_numericas):
    sns.regplot(
        x           = dfc[colum],
        y           = dfc['precio'],
        color       = "gray",
        marker      = '.',
        scatter_kws = {"alpha":0.4},
        line_kws    = {"color":"r","alpha":0.7},
        ax          = axes[i]
    )
    axes[i].set_title(f"precio vs {colum}", fontsize = 7, fontweight = "bold")
    #axes[i].ticklabel_format(style='sci', scilimits=(-4,4), axis='both')
    axes[i].yaxis.set_major_formatter(ticker.EngFormatter())
    axes[i].xaxis.set_major_formatter(ticker.EngFormatter())
    axes[i].tick_params(labelsize = 6)
    axes[i].set_xlabel("")
    axes[i].set_ylabel("")

# Se eliminan los axes vacíos
for i in [10,11]:
    fig.delaxes(axes[i])

fig.tight_layout()
plt.subplots_adjust(top=0.9)
fig.suptitle('Correlación con precio', fontsize = 10, fontweight = "bold")

# %%
#Pearson
print("Método Prearson", dfc.precio.corr(df.precio_terreno, method='pearson')
# 0,75 a 1 es alta correlación. Indicaría que una de las dos caracterías es opcional para retirar del modelo.
# Out:
# 0.5674371845783236

# %%
#Kendall
print("Método Kendall", dfc.precio.corr(df.precio_terreno, method='kendall'))
# 0,75 a 1 es alta correlación. Indicaría que una de las dos caracterías es opcional para retirar del modelo.
# Out:
# Método Spearman 0.37820151991728024

# %%
#Spearman
print("Método Spearman", dfc.precio.corr(df.precio_terreno, method='Spearman'))
# 0,75 a 1 es alta correlación. Indicaría que una de las dos caracterías es opcional para retirar del modelo.

# %%
matriz_correlacion=dfc.corr(method='spearman')
matriz_correlacion
# Out:
# <ipython-input-217-709dd43e5355>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   matriz_correlacion=dfc.corr(method='spearman')
#                      precio  metros_totales  antiguedad  precio_terreno  \
# precio             1.000000        0.321361   -0.314987        0.528530
# metros_totales     0.321361        1.000000    0.036340        0.157192
# antiguedad        -0.314987        0.036340    1.000000       -0.023402
# precio_terreno     0.528530        0.157192   -0.023402        1.000000
# metros_habitables  0.739740        0.348609   -0.286500        0.426593
# universitarios     0.202464        0.057987    0.145163        0.380035
# dormitorios        0.511947        0.389481   -0.051943        0.317145
# chimenea           0.378824        0.173465   -0.049072        0.266730
# ...

# %%
sns.heatmap(matriz_correlacion, annot=True)
# Out:
# <Axes: >

# %%
dfc.drop("MetrosPorSalon",axis=1,inplace=True)

# %%
# Heatmap matriz de correlaciones
# ==============================================================================
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(6, 6))

sns.heatmap(
    matriz_correlacion,
    annot     = True,
    cbar      = True,
    annot_kws = {"size": 6},
    vmin      = -1,
    vmax      = 1,
    center    = 0,
    cmap      = sns.diverging_palette(20, 220, n=200),
    square    = True,
    ax        = ax
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation = 45,
    horizontalalignment = 'right',
)

ax.tick_params(labelsize = 8)

# %%
#Borrar metroporSalon
